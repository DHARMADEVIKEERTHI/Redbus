# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver import ActionChains
import time
import pandas as pd
from selenium.webdriver.support import expected_conditions as EC
import mysql.connector

# Connect Database
db_connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="boot",
    database="redbus"
)
cursor = db_connection.cursor()
print("Database connected Successfully")

# SQL to create table
create_table_query = """
CREATE TABLE IF NOT EXISTS BusDetails(
    id INT PRIMARY KEY AUTO_INCREMENT,
    route_name VARCHAR(255),
    route_link VARCHAR(255),
    bus_name VARCHAR(255),
    bus_type VARCHAR(255),
    departing_time TEXT,
    duration VARCHAR(50),
    reaching_time TEXT,
    star_rating TEXT,
    price VARCHAR(50),
    seat_availability TEXT
);
"""
cursor.execute(create_table_query)
print("Table created successfully")

# Initialize the WebDriver
driver = webdriver.Chrome()
driver.implicitly_wait(5)
wait = WebDriverWait(driver, 30)

# Navigate to the JKSRTC Bus Routes page
driver.get('https://www.redbus.in/online-booking/jksrtc')
driver.maximize_window()
time.sleep(2)

# Scrape route data
route_data = []
def scrape_routes():
    routes = driver.find_elements(By.XPATH, "//a[@class='route']")
    for route in routes:
        route_data.append({
            'Route Name': route.text,
            'Route Link': route.get_attribute('href')
        })
scrape_routes()
print("scraped routes successfully")

# Scroll to load more routes
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# Pagination to collect routes from multiple pages
for page_number in range(1, 6):
    try:
        pagination_container = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')))
        next_page_button = pagination_container.find_element(By.XPATH, f'.//div[contains(@class,"DC_117_pageTabs") and text()="{page_number + 1}"]')

        actions = ActionChains(driver)
        actions.move_to_element(next_page_button).perform()
        next_page_button.click()
        time.sleep(1)

        wait.until(EC.text_to_be_present_in_element((By.XPATH, f'.//div[contains(@class,"DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))
        time.sleep(2)

        scrape_routes()

    except Exception as e:
        print(e)
        break

def collect_bus_details():
    alldetails = []
    for data in route_data:
        link = data['Route Link']
        route_name = data['Route Name']
        try:
            driver.get(link)
            time.sleep(2)

            # Click the 'View Buses' button if it exists
            try:
                # Wait for the button to be clickable
                view_buses_buttons = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[@class='button']")))
                
                for view_buses_button in view_buses_buttons:
                    wait.until(EC.element_to_be_clickable(view_buses_button)).click()
                    time.sleep(5)
            except Exception as e:
                print(e)

            # Scroll to load more buses
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(5)

            bus_containers = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[contains(@class, 'clearfix bus-item')]")))
            
            for bus_container in bus_containers:
                try:
                    busname = bus_container.find_element(By.XPATH, ".//div[@class='travels lh-24 f-bold d-color']").text
                    bustype = bus_container.find_element(By.XPATH, ".//div[@class='bus-type f-12 m-top-16 l-color evBus']").text
                    departuretiming = bus_container.find_element(By.XPATH, ".//div[@class='dp-time f-19 d-color f-bold']").text
                    duration = bus_container.find_element(By.XPATH, ".//div[@class='dur l-color lh-24']").text
                    reachtiming = bus_container.find_element(By.XPATH, ".//div[@class='bp-time f-19 d-color disp-Inline']").text
                    rating = bus_container.find_element(By.XPATH, ".//div[@class='rating-sec lh-24']").text
                    price = bus_container.find_element(By.XPATH, ".//span[contains(@class,'f-19 f-bold') or contains(@class,'f-bold f-19')]").text
                    seat = bus_container.find_element(By.XPATH, ".//div[contains(@class, 'seat-left m-top-30') or contains(@class,'seat-left m-top-16')]").text
                    
                    details = {
                        'Route Name': route_name,
                        'Route Link': link,
                        'Bus Name': busname,
                        'Bus Type': bustype,
                        'Departing Time': departuretiming,
                        'Duration': duration,
                        'Reaching Time': reachtiming,
                        'Star Rating': rating,
                        'Price': price,
                        'Seat Availability': seat,
                    }

                    # Check if the details already exist in the list
                    if details not in alldetails:
                        print(details)
                        alldetails.append(details)

                        # Insert data into the database
                        insert_query = """
                        INSERT IGNORE INTO BusDetails (route_name, route_link, bus_name, bus_type, departing_time, duration, reaching_time, star_rating, price, seat_availability)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                        """
                        cursor.execute(insert_query, (
                            details['Route Name'],
                            details['Route Link'],
                            details['Bus Name'],
                            details['Bus Type'],
                            details['Departing Time'],
                            details['Duration'],
                            details['Reaching Time'],
                            details['Star Rating'],
                            details['Price'],
                            details['Seat Availability']
                        ))
                        db_connection.commit()

                except Exception as e:
                    print(e)

        except Exception as e:
            print(e)
    return alldetails

# Collect bus details and save to CSV
route_details = collect_bus_details()
df = pd.DataFrame(route_details)
df.to_csv("JK.csv", index=False)

# Close the WebDriver
driver.quit()

# Close the Database Connection
cursor.close()
db_connection.close()
# Out:
# Database connected Successfully
# Table created successfully
# scraped routes successfully
# Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6EE6038A5+3004357]
# 	(No symbol) [0x00007FF6EE299970]
# 	(No symbol) [0x00007FF6EE14582A]
# 	(No symbol) [0x00007FF6EE195B8E]
# 	(No symbol) [0x00007FF6EE195E7C]
# 	(No symbol) [0x00007FF6EE1DEC27]
# 	(No symbol) [0x00007FF6EE1BBC1F]
# 	(No symbol) [0x00007FF6EE1DBA4C]
# 	(No symbol) [0x00007FF6EE1BB983]
# 	(No symbol) [0x00007FF6EE187628]
# 	(No symbol) [0x00007FF6EE188791]
# 	GetHandleVerifier [0x00007FF6EE62A00D+3161901]
# 	GetHandleVerifier [0x00007FF6EE67E060+3506048]
# 	GetHandleVerifier [0x00007FF6EE67400D+3465005]
# 	GetHandleVerifier [0x00007FF6EE3F0EEB+830987]
# 	(No symbol) [0x00007FF6EE2A467F]
# 	(No symbol) [0x00007FF6EE2A09D4]
# 	(No symbol) [0x00007FF6EE2A0B6D]
# 	(No symbol) [0x00007FF6EE290149]
# 	BaseThreadInitThunk [0x00007FFD56D4259D+29]
# 	RtlUserThreadStart [0x00007FFD5868AF38+40]
#
# Message:
#
# {'Route Name': 'Srinagar to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/srinagar-to-jammu', 'Bus Name': 'Jamna Travels-Jammu', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '19:00', 'Duration': '11h 45m', 'Reaching Time': '06:45', 'Star Rating': '2.3', 'Price': '999', 'Seat Availability': '10 Seats available'}
# {'Route Name': 'Srinagar to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/srinagar-to-jammu', 'Bus Name': 'New Pal Travels', 'Bus Type': 'NON A/C Seater / Sleeper (2+2)', 'Departing Time': '19:00', 'Duration': '10h 00m', 'Reaching Time': '05:00', 'Star Rating': '1.7', 'Price': '679', 'Seat Availability': '39 Seats available'}
# Message:
#
# {'Route Name': 'Delhi to Srinagar', 'Route Link': 'https://www.redbus.in/bus-tickets/delhi-to-srinagar', 'Bus Name': 'Zingbus Plus', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '20:00', 'Duration': '19h 20m', 'Reaching Time': '15:20', 'Star Rating': '5.0', 'Price': '2161', 'Seat Availability': '13 Seats available'}
# {'Route Name': 'Delhi to Srinagar', 'Route Link': 'https://www.redbus.in/bus-tickets/delhi-to-srinagar', 'Bus Name': 'Zingbus Plus', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '21:35', 'Duration': '19h 30m', 'Reaching Time': '17:05', 'Star Rating': '4.8', 'Price': '2544', 'Seat Availability': '11 Seats available'}
# Message:
#
# {'Route Name': 'Jammu (j and k) to Srinagar', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-srinagar', 'Bus Name': 'Jamna Travels-Jammu', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '21:30', 'Duration': '10h 30m', 'Reaching Time': '08:00', 'Star Rating': '1.2', 'Price': '649', 'Seat Availability': '32 Seats available'}
# {'Route Name': 'Jammu (j and k) to Srinagar', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-srinagar', 'Bus Name': 'New Pal Travels', 'Bus Type': 'NON A/C Seater / Sleeper (2+2)', 'Departing Time': '21:15', 'Duration': '10h 00m', 'Reaching Time': '07:15', 'Star Rating': '2.1', 'Price': '679', 'Seat Availability': '34 Seats available'}
# Message:
#
# {'Route Name': 'Katra (jammu and kashmir) to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/katra-to-jammu', 'Bus Name': 'FlixBus', 'Bus Type': 'Bharat Benz A/C Sleeper (2+1)', 'Departing Time': '18:30', 'Duration': '01h 30m', 'Reaching Time': '20:00', 'Star Rating': '4.0', 'Price': '88.39', 'Seat Availability': '22 Seats available'}
# {'Route Name': 'Katra (jammu and kashmir) to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/katra-to-jammu', 'Bus Name': 'Zingbus Plus', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '18:45', 'Duration': '01h 25m', 'Reaching Time': '20:10', 'Star Rating': '4.4', 'Price': '103', 'Seat Availability': '42 Seats available'}
# {'Route Name': 'Katra (jammu and kashmir) to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/katra-to-jammu', 'Bus Name': 'City Land Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '19:00', 'Duration': '01h 30m', 'Reaching Time': '20:30', 'Star Rating': '3.5', 'Price': '650', 'Seat Availability': '39 Seats available'}
# {'Route Name': 'Katra (jammu and kashmir) to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/katra-to-jammu', 'Bus Name': 'Zingbus Plus', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '19:50', 'Duration': '01h 30m', 'Reaching Time': '21:20', 'Star Rating': '4.4', 'Price': '123', 'Seat Availability': '29 Seats available'}
# {'Route Name': 'Katra (jammu and kashmir) to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/katra-to-jammu', 'Bus Name': 'SHRI KRISHNA TRAVELS (JAI SHREE GANESH YATRA CO.)', 'Bus Type': 'A/C Seater/Sleeper (2+1)', 'Departing Time': '20:00', 'Duration': '01h 00m', 'Reaching Time': '21:00', 'Star Rating': '3.7', 'Price': '1099', 'Seat Availability': '18 Seats available'}
# {'Route Name': 'Katra (jammu and kashmir) to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/katra-to-jammu', 'Bus Name': 'FlixBus', 'Bus Type': 'Bharat Benz A/C Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '01h 25m', 'Reaching Time': '22:25', 'Star Rating': '4.0', 'Price': '88.39', 'Seat Availability': '28 Seats available'}
# {'Route Name': 'Katra (jammu and kashmir) to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/katra-to-jammu', 'Bus Name': 'New Pal Travels', 'Bus Type': 'A/C Sleeper (2+2)', 'Departing Time': '23:00', 'Duration': '01h 30m', 'Reaching Time': '00:30', 'Star Rating': '3.6', 'Price': '449', 'Seat Availability': '34 Seats available'}
# {'Route Name': 'Katra (jammu and kashmir) to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/katra-to-jammu', 'Bus Name': 'KN Nehra Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '19:00', 'Duration': '01h 30m', 'Reaching Time': '20:30', 'Star Rating': '2.9', 'Price': '599', 'Seat Availability': '28 Seats available'}
# {'Route Name': 'Katra (jammu and kashmir) to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/katra-to-jammu', 'Bus Name': 'VGO BUS', 'Bus Type': 'A/C Seater/Sleeper (2+1)', 'Departing Time': '18:30', 'Duration': '01h 00m', 'Reaching Time': '19:30', 'Star Rating': '3.9', 'Price': '1800', 'Seat Availability': '40 Seats available'}
# {'Route Name': 'Katra (jammu and kashmir) to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/katra-to-jammu', 'Bus Name': 'SHRI KRISHNA TRAVELS (JAI SHREE GANESH YATRA CO.)', 'Bus Type': 'VE A/C Seater / Sleeper (2+1)', 'Departing Time': '19:00', 'Duration': '01h 00m', 'Reaching Time': '20:00', 'Star Rating': '3.7', 'Price': '1099', 'Seat Availability': '38 Seats available'}
# Message:
#
# Message:
#
# Message:
#
# Message:
#
# Message:
#
# {'Route Name': 'Jammu (j and k) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-chandigarh', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '17:35', 'Duration': '07h 55m', 'Reaching Time': '01:30', 'Star Rating': '4.5', 'Price': '449', 'Seat Availability': '19 Seats available'}
# {'Route Name': 'Jammu (j and k) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-chandigarh', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'VE A/C Seater / Sleeper (2+1)', 'Departing Time': '22:15', 'Duration': '06h 55m', 'Reaching Time': '05:10', 'Star Rating': '4.4', 'Price': '467', 'Seat Availability': '16 Seats available'}
# {'Route Name': 'Jammu (j and k) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-chandigarh', 'Bus Name': 'IntrCity SmartBus', 'Bus Type': 'VE A/C Seater / Sleeper (2+1)', 'Departing Time': '21:35', 'Duration': '07h 25m', 'Reaching Time': '05:00', 'Star Rating': '4.7', 'Price': '489', 'Seat Availability': '23 Seats available'}
# {'Route Name': 'Jammu (j and k) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-chandigarh', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Bharat Benz A/C Sleeper (2+1)', 'Departing Time': '21:30', 'Duration': '07h 20m', 'Reaching Time': '04:50', 'Star Rating': '4.4', 'Price': '657', 'Seat Availability': '7 Seats available'}
# {'Route Name': 'Jammu (j and k) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-chandigarh', 'Bus Name': 'Zingbus Plus', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '21:20', 'Duration': '07h 40m', 'Reaching Time': '05:00', 'Star Rating': '4.7', 'Price': '584', 'Seat Availability': '12 Seats available'}
# {'Route Name': 'Jammu (j and k) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-chandigarh', 'Bus Name': 'Harikesh Tour N Travels', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '21:10', 'Duration': '07h 20m', 'Reaching Time': '04:30', 'Star Rating': '4.2', 'Price': '534', 'Seat Availability': '1 Seat available'}
# {'Route Name': 'Jammu (j and k) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-chandigarh', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Bharat Benz A/C Sleeper (2+1)', 'Departing Time': '21:15', 'Duration': '07h 15m', 'Reaching Time': '04:30', 'Star Rating': '4.6', 'Price': '599', 'Seat Availability': '5 Seats available'}
# {'Route Name': 'Jammu (j and k) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-chandigarh', 'Bus Name': 'Radhe Travels', 'Bus Type': 'Bharat Benz A/C Sleeper (2+1)', 'Departing Time': '21:25', 'Duration': '07h 50m', 'Reaching Time': '05:15', 'Star Rating': '3.9', 'Price': '485', 'Seat Availability': '2 Seats available'}
# {'Route Name': 'Jammu (j and k) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-chandigarh', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '20:50', 'Duration': '07h 30m', 'Reaching Time': '04:20', 'Star Rating': '4.4', 'Price': '490', 'Seat Availability': '17 Seats available'}
# {'Route Name': 'Jammu (j and k) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/jammu-to-chandigarh', 'Bus Name': 'Moon Light Travels Katra', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '20:15', 'Duration': '08h 05m', 'Reaching Time': '04:20', 'Star Rating': '4.4', 'Price': '637', 'Seat Availability': '5 Seats available'}
# Message:
#
# {'Route Name': 'Chandigarh to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/chandigarh-to-jammu', 'Bus Name': 'Radhe Travels', 'Bus Type': 'Bharat Benz A/C Sleeper (2+1)', 'Departing Time': '21:20', 'Duration': '07h 25m', 'Reaching Time': '04:45', 'Star Rating': '4.3', 'Price': '449', 'Seat Availability': '19 Seats available'}
# {'Route Name': 'Chandigarh to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/chandigarh-to-jammu', 'Bus Name': 'Zimindara Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '22:30', 'Duration': '07h 00m', 'Reaching Time': '05:30', 'Star Rating': '4.3', 'Price': '437', 'Seat Availability': '18 Seats available'}
# {'Route Name': 'Chandigarh to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/chandigarh-to-jammu', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '22:50', 'Duration': '07h 10m', 'Reaching Time': '06:00', 'Star Rating': '4.4', 'Price': '490', 'Seat Availability': '14 Seats available'}
# {'Route Name': 'Chandigarh to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/chandigarh-to-jammu', 'Bus Name': 'AdMoon Light Travels Katra', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '21:15', 'Duration': '07h 15m', 'Reaching Time': '04:30', 'Star Rating': '4.6', 'Price': '552', 'Seat Availability': '4 Seats available'}
# {'Route Name': 'Chandigarh to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/chandigarh-to-jammu', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '23:35', 'Duration': '07h 10m', 'Reaching Time': '06:45', 'Star Rating': '4.8', 'Price': '608', 'Seat Availability': '9 Seats available'}
# {'Route Name': 'Chandigarh to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/chandigarh-to-jammu', 'Bus Name': 'Jamna Travels-Jammu', 'Bus Type': 'AshokLeyland Stile A/C', 'Departing Time': '20:30', 'Duration': '08h 00m', 'Reaching Time': '04:30', 'Star Rating': '4.2', 'Price': '531', 'Seat Availability': '6 Seats available'}
# {'Route Name': 'Chandigarh to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/chandigarh-to-jammu', 'Bus Name': 'Moon Light Travels Katra', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '22:00', 'Duration': '07h 25m', 'Reaching Time': '05:25', 'Star Rating': '4.7', 'Price': '637', 'Seat Availability': '3 Seats available'}
# {'Route Name': 'Chandigarh to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/chandigarh-to-jammu', 'Bus Name': 'AdNew Pal Travels', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '19:30', 'Duration': '10h 15m', 'Reaching Time': '05:45', 'Star Rating': '3.8', 'Price': '450', 'Seat Availability': '13 Seats available'}
# {'Route Name': 'Chandigarh to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/chandigarh-to-jammu', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '23:05', 'Duration': '06h 55m', 'Reaching Time': '06:00', 'Star Rating': '4.6', 'Price': '450', 'Seat Availability': '6 Seats available'}
# {'Route Name': 'Chandigarh to Jammu (j and k)', 'Route Link': 'https://www.redbus.in/bus-tickets/chandigarh-to-jammu', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Volvo 9600 Multi-Axle A/C Sleeper (2+1)', 'Departing Time': '23:50', 'Duration': '07h 10m', 'Reaching Time': '07:00', 'Star Rating': '4.2', 'Price': '812', 'Seat Availability': '1 Seat available'}
# Message:
#
# Message:

# %%
df
