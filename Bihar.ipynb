# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver import ActionChains
import time
import pandas as pd
from selenium.webdriver.support import expected_conditions as EC
import mysql.connector

# Connect Database
db_connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="boot",
    database="redbus"
)
cursor = db_connection.cursor()
print("Database connected Successfully")

# SQL to create table
create_table_query = """
CREATE TABLE IF NOT EXISTS BusDetails(
    id INT PRIMARY KEY AUTO_INCREMENT,
    state VARCHAR(100) DEFAULT 'Bihar',
    route_name VARCHAR(255),
    route_link VARCHAR(255),
    bus_name VARCHAR(255),
    bus_type VARCHAR(255),
    departing_time TEXT,
    duration VARCHAR(50),
    reaching_time TEXT,
    star_rating TEXT,
    price VARCHAR(50),
    seat_availability TEXT
);
"""
cursor.execute(create_table_query)
print("Table created successfully")

# Initialize the WebDriver
driver = webdriver.Chrome()
driver.implicitly_wait(5)
wait = WebDriverWait(driver, 30)

# Navigate to the BSRTC Bus Routes page
driver.get('https://www.redbus.in/online-booking/bihar-state-road-transport-corporation-bsrtc/?utm_source=rtchometile')
driver.maximize_window()
time.sleep(2)

# Scrape route data
route_data = []
def scrape_routes():
    routes = driver.find_elements(By.XPATH, "//a[@class='route']")
    for route in routes:
        route_data.append({
            'Route Name': route.text,
            'Route Link': route.get_attribute('href')
        })
scrape_routes()
print("scraped routes successfully")

# Scroll to load more routes
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# Pagination to collect routes from multiple pages
for page_number in range(1, 6):
    try:
        pagination_container = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')))
        next_page_button = pagination_container.find_element(By.XPATH, f'.//div[contains(@class,"DC_117_pageTabs") and text()="{page_number + 1}"]')

        actions = ActionChains(driver)
        actions.move_to_element(next_page_button).perform()
        next_page_button.click()
        time.sleep(1)

        wait.until(EC.text_to_be_present_in_element((By.XPATH, f'.//div[contains(@class,"DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))
        time.sleep(2)

        scrape_routes()

    except Exception as e:
        print(e)
        break

def collect_bus_details():
    alldetails = []
    for data in route_data:
        link = data['Route Link']
        route_name = data['Route Name']
        try:
            driver.get(link)
            time.sleep(2)

            # Click the 'View Buses' button if it exists
            try:
                # Wait for the button to be clickable
                view_buses_buttons = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[@class='button']")))
                
                for view_buses_button in view_buses_buttons:
                    wait.until(EC.element_to_be_clickable(view_buses_button)).click()
                    time.sleep(5)
            except Exception as e:
                print(e)

            # Scroll to load more buses
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(5)

            bus_containers = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[contains(@class, 'clearfix bus-item')]")))
            
            for bus_container in bus_containers:
                try:
                    busname = bus_container.find_element(By.XPATH, ".//div[@class='travels lh-24 f-bold d-color']").text
                    bustype = bus_container.find_element(By.XPATH, ".//div[@class='bus-type f-12 m-top-16 l-color evBus']").text
                    departuretiming = bus_container.find_element(By.XPATH, ".//div[@class='dp-time f-19 d-color f-bold']").text
                    duration = bus_container.find_element(By.XPATH, ".//div[@class='dur l-color lh-24']").text
                    reachtiming = bus_container.find_element(By.XPATH, ".//div[@class='bp-time f-19 d-color disp-Inline']").text
                    rating = bus_container.find_element(By.XPATH, ".//div[@class='rating-sec lh-24']").text
                    price = bus_container.find_element(By.XPATH, ".//span[contains(@class,'f-19 f-bold') or contains(@class,'f-bold f-19')]").text
                    seat = bus_container.find_element(By.XPATH, ".//div[contains(@class, 'seat-left m-top-30') or contains(@class,'seat-left m-top-16')]").text
                    
                    details = {
                        'State': "Bihar",
                        'Route Name': route_name,
                        'Route Link': link,
                        'Bus Name': busname,
                        'Bus Type': bustype,
                        'Departing Time': departuretiming,
                        'Duration': duration,
                        'Reaching Time': reachtiming,
                        'Star Rating': rating,
                        'Price': price,
                        'Seat Availability': seat,
                    }

                    # Check if the details already exist in the list
                    if details not in alldetails:
                        print(details)
                        alldetails.append(details)

                        # Insert data into the database
                        insert_query = """
                        INSERT IGNORE INTO BusDetails (state, route_name, route_link, bus_name, bus_type, departing_time, duration, reaching_time, star_rating, price, seat_availability)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                        """
                        cursor.execute(insert_query, (
                            details['State'],
                            details['Route Name'],
                            details['Route Link'],
                            details['Bus Name'],
                            details['Bus Type'],
                            details['Departing Time'],
                            details['Duration'],
                            details['Reaching Time'],
                            details['Star Rating'],
                            details['Price'],
                            details['Seat Availability']
                        ))
                        db_connection.commit()

                except Exception as e:
                    print(e)

        except Exception as e:
            print(e)
    return alldetails

# Collect bus details and save to CSV
route_details = collect_bus_details()
df = pd.DataFrame(route_details)
df.to_csv("Bihar.csv", index=False)

# Close the WebDriver
driver.quit()

# Close the Database Connection
cursor.close()
db_connection.close()
# Out:
# Database connected Successfully
# Table created successfully
# scraped routes successfully
# Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B1966CB5+28821]
# 	(No symbol) [0x00007FF7B18D3840]
# 	(No symbol) [0x00007FF7B177578A]
# 	(No symbol) [0x00007FF7B17C91BE]
# 	(No symbol) [0x00007FF7B17C94AC]
# 	(No symbol) [0x00007FF7B1812647]
# 	(No symbol) [0x00007FF7B17EF33F]
# 	(No symbol) [0x00007FF7B180F412]
# 	(No symbol) [0x00007FF7B17EF0A3]
# 	(No symbol) [0x00007FF7B17BA778]
# 	(No symbol) [0x00007FF7B17BB8E1]
# 	GetHandleVerifier [0x00007FF7B1C9FCAD+3408013]
# 	GetHandleVerifier [0x00007FF7B1CB741F+3504127]
# 	GetHandleVerifier [0x00007FF7B1CAB5FD+3455453]
# 	GetHandleVerifier [0x00007FF7B1A2BDBB+835995]
# 	(No symbol) [0x00007FF7B18DEB5F]
# 	(No symbol) [0x00007FF7B18DA814]
# 	(No symbol) [0x00007FF7B18DA9AD]
# 	(No symbol) [0x00007FF7B18CA199]
# 	BaseThreadInitThunk [0x00007FFBDFB4259D+29]
# 	RtlUserThreadStart [0x00007FFBE0A8AF38+40]
#
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Bettiah', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-bettiah', 'Bus Name': 'Jai Hanuman Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '22:20', 'Duration': '06h 40m', 'Reaching Time': '05:00', 'Star Rating': '3.6', 'Price': '495', 'Seat Availability': '53 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Bettiah', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-bettiah', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '22:40', 'Duration': '05h 20m', 'Reaching Time': '04:00', 'Star Rating': '3.4', 'Price': '450', 'Seat Availability': '22 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Bettiah', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-bettiah', 'Bus Name': 'Vivek Travels', 'Bus Type': 'A/C Seater (2+2)', 'Departing Time': '13:25', 'Duration': '07h 00m', 'Reaching Time': '20:25', 'Star Rating': '1.0', 'Price': '450', 'Seat Availability': '45 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Bettiah', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-bettiah', 'Bus Name': 'Vivek Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '13:30', 'Duration': '07h 00m', 'Reaching Time': '20:30', 'Star Rating': '1.0', 'Price': '400', 'Seat Availability': '72 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Bettiah', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-bettiah', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '20:28', 'Duration': '05h 32m', 'Reaching Time': '02:00', 'Star Rating': '2.0', 'Price': '500', 'Seat Availability': '3 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Bettiah', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-bettiah', 'Bus Name': 'V.I.P Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '21:40', 'Duration': '06h 00m', 'Reaching Time': '03:40', 'Star Rating': '2.8', 'Price': '350', 'Seat Availability': '51 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-motihari', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 150571', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '21:20', 'Duration': '03h 40m', 'Reaching Time': '01:00', 'Star Rating': '3.7', 'Price': '230', 'Seat Availability': '32 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-motihari', 'Bus Name': 'Jai Hanuman Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '22:20', 'Duration': '04h 55m', 'Reaching Time': '03:15', 'Star Rating': '3.0', 'Price': '495', 'Seat Availability': '54 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-motihari', 'Bus Name': 'Saurabh Travels', 'Bus Type': 'A/C Seater Push Back (2+2)', 'Departing Time': '10:30', 'Duration': '03h 30m', 'Reaching Time': '14:00', 'Star Rating': '1.0', 'Price': '350', 'Seat Availability': '41 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-motihari', 'Bus Name': 'Siddhi Vinayak (BSRTC U/T)', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '12:15', 'Duration': '04h 00m', 'Reaching Time': '16:15', 'Star Rating': '2.2', 'Price': '220', 'Seat Availability': '35 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-motihari', 'Bus Name': 'Siddhi Vinayak (BSRTC U/T)', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '15:30', 'Duration': '04h 00m', 'Reaching Time': '19:30', 'Star Rating': '2.2', 'Price': '220', 'Seat Availability': '35 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-motihari', 'Bus Name': 'Jai Hanuman Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '22:00', 'Duration': '06h 00m', 'Reaching Time': '04:00', 'Star Rating': '4.5', 'Price': '495', 'Seat Availability': '54 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-motihari', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '13:53', 'Duration': '05h 27m', 'Reaching Time': '19:20', 'Star Rating': '2.3', 'Price': '400', 'Seat Availability': '12 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-motihari', 'Bus Name': 'Panwar Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '18:10', 'Duration': '03h 25m', 'Reaching Time': '21:35', 'Star Rating': '2.8', 'Price': '1074', 'Seat Availability': '28 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-motihari', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '20:28', 'Duration': '03h 02m', 'Reaching Time': '23:30', 'Star Rating': '1.2', 'Price': '500', 'Seat Availability': '3 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 146159', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '14:30', 'Duration': '05h 00m', 'Reaching Time': '19:30', 'Star Rating': '2.6', 'Price': '285', 'Seat Availability': '25 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 170674', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '20:30', 'Duration': '05h 30m', 'Reaching Time': '02:00', 'Star Rating': '2.3', 'Price': '285', 'Seat Availability': '25 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Jai Mata Di', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '12:30', 'Duration': '06h 20m', 'Reaching Time': '18:50', 'Star Rating': '4.1', 'Price': '405', 'Seat Availability': '40 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Jai Mata Di', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '12:39', 'Duration': '06h 06m', 'Reaching Time': '18:45', 'Star Rating': '4.1', 'Price': '405', 'Seat Availability': '41 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Jai Mata Di', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '12:41', 'Duration': '06h 24m', 'Reaching Time': '19:05', 'Star Rating': '4.1', 'Price': '405', 'Seat Availability': '41 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Jai Mata Di', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '12:44', 'Duration': '06h 16m', 'Reaching Time': '19:00', 'Star Rating': '4.1', 'Price': '405', 'Seat Availability': '41 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Vivek Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '13:15', 'Duration': '07h 15m', 'Reaching Time': '20:30', 'Star Rating': '1.0', 'Price': '450', 'Seat Availability': '54 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Saurabh Travels', 'Bus Type': 'A/C Seater Push Back (2+2)', 'Departing Time': '15:00', 'Duration': '17h 45m', 'Reaching Time': '08:45', 'Star Rating': '1.0', 'Price': '450', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Saurabh Travels', 'Bus Type': 'A/C Seater Push Back (2+2)', 'Departing Time': '15:00', 'Duration': '06h 00m', 'Reaching Time': '21:00', 'Star Rating': '1.0', 'Price': '450', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Saurabh Travels', 'Bus Type': 'A/C Seater Push Back (2+2)', 'Departing Time': '15:15', 'Duration': '06h 05m', 'Reaching Time': '21:20', 'Star Rating': '1.0', 'Price': '450', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Saurabh Travels', 'Bus Type': 'A/C Seater Push Back (2+2)', 'Departing Time': '15:21', 'Duration': '06h 24m', 'Reaching Time': '21:45', 'Star Rating': '1.0', 'Price': '450', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Saurabh Travels', 'Bus Type': 'A/C Seater Push Back (2+2)', 'Departing Time': '15:30', 'Duration': '06h 45m', 'Reaching Time': '22:15', 'Star Rating': '1.0', 'Price': '450', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Saurabh Travels', 'Bus Type': 'A/C Seater Push Back (2+2)', 'Departing Time': '15:37', 'Duration': '06h 38m', 'Reaching Time': '22:15', 'Star Rating': '1.0', 'Price': '450', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Jai Hanuman Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '21:55', 'Duration': '07h 36m', 'Reaching Time': '05:31', 'Star Rating': '2.5', 'Price': '495', 'Seat Availability': '40 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Bettiah to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '22:00', 'Duration': '07h 00m', 'Reaching Time': '05:00', 'Star Rating': '2.0', 'Price': '500', 'Seat Availability': '10 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Gopalganj (Bihar) to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/gopalganj-to-delhi', 'Bus Name': 'Chandani Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '18:00', 'Duration': '16h 00m', 'Reaching Time': '10:00', 'Star Rating': '1.2', 'Price': '1299', 'Seat Availability': '4 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Gopalganj (Bihar) to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/gopalganj-to-delhi', 'Bus Name': 'ROYAL TRAVELS AND CARGO', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '17:30', 'Duration': '15h 00m', 'Reaching Time': '08:30', 'Star Rating': '1.8', 'Price': '1296', 'Seat Availability': '24 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Gopalganj (Bihar) to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/gopalganj-to-delhi', 'Bus Name': 'Travel Point World LLP', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '20:20', 'Duration': '14h 30m', 'Reaching Time': '10:50', 'Star Rating': '3.2', 'Price': '1614', 'Seat Availability': '31 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Gopalganj (Bihar) to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/gopalganj-to-delhi', 'Bus Name': 'Rajdhani Express', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '16:00', 'Duration': '17h 00m', 'Reaching Time': '09:00', 'Star Rating': '1.7', 'Price': '1631', 'Seat Availability': '14 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Gopalganj (Bihar) to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/gopalganj-to-delhi', 'Bus Name': 'Rajdhani Express', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '15:00', 'Duration': '16h 00m', 'Reaching Time': '07:00', 'Star Rating': '1.6', 'Price': '1424', 'Seat Availability': '26 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Gopalganj (Bihar) to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/gopalganj-to-delhi', 'Bus Name': 'Baba Khatushyam Travels Pvt Ltd', 'Bus Type': 'A/C Seater / Sleeper (3+1)', 'Departing Time': '19:00', 'Duration': '16h 49m', 'Reaching Time': '11:49', 'Star Rating': '1.2', 'Price': '1499', 'Seat Availability': '14 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Gopalganj (Bihar) to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/gopalganj-to-delhi', 'Bus Name': 'Ashok Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '19:00', 'Duration': '16h 00m', 'Reaching Time': '11:00', 'Star Rating': '2.3', 'Price': '2529', 'Seat Availability': '18 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Gopalganj (Bihar) to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/gopalganj-to-delhi', 'Bus Name': 'Shree Balajee Travels And Cargo', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '20:00', 'Duration': '18h 30m', 'Reaching Time': '14:30', 'Star Rating': '1.3', 'Price': '1709', 'Seat Availability': '72 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Gopalganj (Bihar) to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/gopalganj-to-delhi', 'Bus Name': 'Armaan Tour & Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '16:50', 'Duration': '20h 10m', 'Reaching Time': '13:00', 'Star Rating': '2.6', 'Price': '1757', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Gopalganj (Bihar) to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/gopalganj-to-delhi', 'Bus Name': 'Bhumi Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '15:30', 'Duration': '17h 00m', 'Reaching Time': '08:30', 'Star Rating': '2.4', 'Price': '1699', 'Seat Availability': '41 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Balmiki Nagar (bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-balmiki-nagar-bihar', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '22:40', 'Duration': '08h 20m', 'Reaching Time': '07:00', 'Star Rating': '2.2', 'Price': '450', 'Seat Availability': '26 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Balmiki Nagar (bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-balmiki-nagar-bihar', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '20:28', 'Duration': '09h 32m', 'Reaching Time': '06:00', 'Star Rating': '1.7', 'Price': '500', 'Seat Availability': '3 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Balmiki Nagar (bihar) to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/balmiki-nagar-bihar-to-patna', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '18:30', 'Duration': '10h 30m', 'Reaching Time': '05:00', 'Star Rating': '2.2', 'Price': '500', 'Seat Availability': '10 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Delhi to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/delhi-to-motihari', 'Bus Name': 'Travel Point World LLP', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '14:30', 'Duration': '16h 30m', 'Reaching Time': '07:00', 'Star Rating': '1.5', 'Price': '1899', 'Seat Availability': '46 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Delhi to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/delhi-to-motihari', 'Bus Name': 'Travel Point World LLP', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '16:00', 'Duration': '16h 01m', 'Reaching Time': '08:01', 'Star Rating': '1.2', 'Price': '1899', 'Seat Availability': '46 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Delhi to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/delhi-to-motihari', 'Bus Name': 'New India Bus Service', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '15:30', 'Duration': '17h 30m', 'Reaching Time': '09:00', 'Star Rating': '1.0', 'Price': '1804', 'Seat Availability': '24 Seats available'}
# Message:
#
# Message:
#
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Purnea', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-purnea', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 142847', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '21:25', 'Duration': '08h 15m', 'Reaching Time': '05:40', 'Star Rating': '3.6', 'Price': '468', 'Seat Availability': '20 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Purnea', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-purnea', 'Bus Name': 'MAA SHANTI TRAVELS', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:25', 'Duration': '08h 55m', 'Reaching Time': '06:20', 'Star Rating': '4.2', 'Price': '739', 'Seat Availability': '10 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Purnea', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-purnea', 'Bus Name': 'MAA SHANTI TRAVELS', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '22:10', 'Duration': '08h 25m', 'Reaching Time': '06:35', 'Star Rating': '4.1', 'Price': '832', 'Seat Availability': '1 Seat available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Purnea', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-purnea', 'Bus Name': 'Divya Rath', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '20:45', 'Duration': '09h 00m', 'Reaching Time': '05:45', 'Star Rating': '4.4', 'Price': '700', 'Seat Availability': '1 Seat available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Purnea', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-purnea', 'Bus Name': 'AITIANA CRUISELINERS', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '20:20', 'Duration': '09h 10m', 'Reaching Time': '05:30', 'Star Rating': '4.2', 'Price': '500', 'Seat Availability': '4 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Purnea', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-purnea', 'Bus Name': 'Raj Bus Services', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '19:25', 'Duration': '09h 40m', 'Reaching Time': '05:05', 'Star Rating': '4.3', 'Price': '463', 'Seat Availability': '11 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Purnea', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-purnea', 'Bus Name': 'Shatabdi Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '09h 00m', 'Reaching Time': '06:00', 'Star Rating': '3.1', 'Price': '650', 'Seat Availability': '16 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Purnea', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-purnea', 'Bus Name': 'Sri Krishna Tours and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '20:30', 'Duration': '08h 50m', 'Reaching Time': '05:20', 'Star Rating': '3.2', 'Price': '600', 'Seat Availability': '20 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Purnea', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-purnea', 'Bus Name': 'Maa Satyabhama Rath', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '09h 00m', 'Reaching Time': '06:00', 'Star Rating': '3.8', 'Price': '600', 'Seat Availability': '11 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Purnea', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-purnea', 'Bus Name': 'Sri Krishna Tours and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:25', 'Duration': '08h 50m', 'Reaching Time': '05:15', 'Star Rating': '3.2', 'Price': '650', 'Seat Availability': '11 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Motihari to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/motihari-to-delhi', 'Bus Name': 'Travel Point World LLP', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '18:20', 'Duration': '16h 30m', 'Reaching Time': '10:50', 'Star Rating': '1.7', 'Price': '1614', 'Seat Availability': '31 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Motihari to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/motihari-to-delhi', 'Bus Name': 'Rajdhani Express', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '15:00', 'Duration': '18h 00m', 'Reaching Time': '09:00', 'Star Rating': '1.7', 'Price': '1631', 'Seat Availability': '14 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Motihari to Delhi', 'Route Link': 'https://www.redbus.in/bus-tickets/motihari-to-delhi', 'Bus Name': 'Baba Khatushyam Travels Pvt Ltd', 'Bus Type': 'A/C Seater / Sleeper (3+1)', 'Departing Time': '17:35', 'Duration': '18h 14m', 'Reaching Time': '11:49', 'Star Rating': '1.7', 'Price': '1499', 'Seat Availability': '14 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Ranchi to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-muzaffarpur', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 153614', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '20:55', 'Duration': '10h 35m', 'Reaching Time': '07:30', 'Star Rating': '3.1', 'Price': '605', 'Seat Availability': '20 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-muzaffarpur', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '19:15', 'Duration': '11h 15m', 'Reaching Time': '06:30', 'Star Rating': '2.7', 'Price': '700', 'Seat Availability': '2 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-muzaffarpur', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '18:45', 'Duration': '09h 30m', 'Reaching Time': '04:15', 'Star Rating': '1.8', 'Price': '1000', 'Seat Availability': '2 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-muzaffarpur', 'Bus Name': 'Tejas Maa Bhawani', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '18:15', 'Duration': '11h 15m', 'Reaching Time': '05:30', 'Star Rating': '1.7', 'Price': '899', 'Seat Availability': '4 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-muzaffarpur', 'Bus Name': 'Tejas Maa Bhawani', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '18:29', 'Duration': '10h 46m', 'Reaching Time': '05:15', 'Star Rating': '1.9', 'Price': '799', 'Seat Availability': '21 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-muzaffarpur', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '20:00', 'Duration': '09h 00m', 'Reaching Time': '05:00', 'Star Rating': '2.3', 'Price': '1200', 'Seat Availability': '2 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-muzaffarpur', 'Bus Name': 'Tejas Maa Bhawani', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '17:45', 'Duration': '11h 45m', 'Reaching Time': '05:30', 'Star Rating': '1.8', 'Price': '725', 'Seat Availability': '21 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-muzaffarpur', 'Bus Name': 'Sri Krishna Rath', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '22:00', 'Duration': '10h 00m', 'Reaching Time': '08:00', 'Star Rating': '1.0', 'Price': '788', 'Seat Availability': '18 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Kathmandu', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-kathmandu', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 166033', 'Bus Type': 'A/C Seater Hi-Tech Push Back (2+2)', 'Departing Time': '13:30', 'Duration': '16h 45m', 'Reaching Time': '06:15', 'Star Rating': '2.3', 'Price': '1015', 'Seat Availability': '23 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Kathmandu', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-kathmandu', 'Bus Name': 'V.I.P Travels', 'Bus Type': 'A/C Seater Hi-Tech Push Back (2+2)', 'Departing Time': '13:15', 'Duration': '16h 15m', 'Reaching Time': '05:30', 'Star Rating': '2.9', 'Price': '1040', 'Seat Availability': '5 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Ranchi to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-patna', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 153614', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '20:55', 'Duration': '08h 35m', 'Reaching Time': '05:30', 'Star Rating': '3.8', 'Price': '500', 'Seat Availability': '20 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-patna', 'Bus Name': 'Mahuli Travels', 'Bus Type': 'A/C Seater/Sleeper (2+1)', 'Departing Time': '21:15', 'Duration': '09h 00m', 'Reaching Time': '06:15', 'Star Rating': '4.0', 'Price': '600', 'Seat Availability': '27 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-patna', 'Bus Name': 'MAA SHANTI TRAVELS', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '22:20', 'Duration': '07h 35m', 'Reaching Time': '05:55', 'Star Rating': '4.6', 'Price': '740', 'Seat Availability': '10 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-patna', 'Bus Name': 'Prithvi Vahan', 'Bus Type': 'Bharat Benz A/C Sleeper (2+1)', 'Departing Time': '21:30', 'Duration': '07h 40m', 'Reaching Time': '05:10', 'Star Rating': '4.7', 'Price': '990', 'Seat Availability': '2 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-patna', 'Bus Name': 'Divya Rath', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '22:10', 'Duration': '07h 20m', 'Reaching Time': '05:30', 'Star Rating': '4.3', 'Price': '1200', 'Seat Availability': '1 Seat available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-patna', 'Bus Name': 'MAA SHANTI TRAVELS', 'Bus Type': 'A/C Seater/Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '09h 35m', 'Reaching Time': '06:35', 'Star Rating': '3.8', 'Price': '601', 'Seat Availability': '20 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-patna', 'Bus Name': 'Rekha Luxury', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:30', 'Duration': '09h 30m', 'Reaching Time': '06:00', 'Star Rating': '3.8', 'Price': '580', 'Seat Availability': '1 Seat available'}
# Message: no such element: Unable to locate element: {"method":"xpath","selector":".//div[@class='rating-sec lh-24']"}
#   (Session info: chrome=131.0.6778.86); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B1966CB5+28821]
# 	(No symbol) [0x00007FF7B18D3840]
# 	(No symbol) [0x00007FF7B177578A]
# 	(No symbol) [0x00007FF7B17C91BE]
# 	(No symbol) [0x00007FF7B17C94AC]
# 	(No symbol) [0x00007FF7B17BC52C]
# 	(No symbol) [0x00007FF7B17EF33F]
# 	(No symbol) [0x00007FF7B17BC3F6]
# 	(No symbol) [0x00007FF7B17EF510]
# 	(No symbol) [0x00007FF7B180F412]
# 	(No symbol) [0x00007FF7B17EF0A3]
# 	(No symbol) [0x00007FF7B17BA778]
# 	(No symbol) [0x00007FF7B17BB8E1]
# 	GetHandleVerifier [0x00007FF7B1C9FCAD+3408013]
# 	GetHandleVerifier [0x00007FF7B1CB741F+3504127]
# 	GetHandleVerifier [0x00007FF7B1CAB5FD+3455453]
# 	GetHandleVerifier [0x00007FF7B1A2BDBB+835995]
# 	(No symbol) [0x00007FF7B18DEB5F]
# 	(No symbol) [0x00007FF7B18DA814]
# 	(No symbol) [0x00007FF7B18DA9AD]
# 	(No symbol) [0x00007FF7B18CA199]
# 	BaseThreadInitThunk [0x00007FFBDFB4259D+29]
# 	RtlUserThreadStart [0x00007FFBE0A8AF38+40]
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":".//div[@class='rating-sec lh-24']"}
#   (Session info: chrome=131.0.6778.86); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B1966CB5+28821]
# 	(No symbol) [0x00007FF7B18D3840]
# 	(No symbol) [0x00007FF7B177578A]
# 	(No symbol) [0x00007FF7B17C91BE]
# 	(No symbol) [0x00007FF7B17C94AC]
# 	(No symbol) [0x00007FF7B17BC52C]
# 	(No symbol) [0x00007FF7B17EF33F]
# 	(No symbol) [0x00007FF7B17BC3F6]
# 	(No symbol) [0x00007FF7B17EF510]
# 	(No symbol) [0x00007FF7B180F412]
# 	(No symbol) [0x00007FF7B17EF0A3]
# 	(No symbol) [0x00007FF7B17BA778]
# 	(No symbol) [0x00007FF7B17BB8E1]
# 	GetHandleVerifier [0x00007FF7B1C9FCAD+3408013]
# 	GetHandleVerifier [0x00007FF7B1CB741F+3504127]
# 	GetHandleVerifier [0x00007FF7B1CAB5FD+3455453]
# 	GetHandleVerifier [0x00007FF7B1A2BDBB+835995]
# 	(No symbol) [0x00007FF7B18DEB5F]
# 	(No symbol) [0x00007FF7B18DA814]
# 	(No symbol) [0x00007FF7B18DA9AD]
# 	(No symbol) [0x00007FF7B18CA199]
# 	BaseThreadInitThunk [0x00007FFBDFB4259D+29]
# 	RtlUserThreadStart [0x00007FFBE0A8AF38+40]
#
# {'State': 'Bihar', 'Route Name': 'Ranchi to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-patna', 'Bus Name': 'Puja Rath', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:30', 'Duration': '09h 00m', 'Reaching Time': '05:30', 'Star Rating': '3.8', 'Price': '540', 'Seat Availability': '15 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Ranchi to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/ranchi-to-patna', 'Bus Name': 'Sadhvi Rath', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:30', 'Duration': '09h 00m', 'Reaching Time': '05:30', 'Star Rating': '3.1', 'Price': '630', 'Seat Availability': '20 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Hazaribagh to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/hazaribagh-to-patna', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 153614', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '23:15', 'Duration': '06h 15m', 'Reaching Time': '05:30', 'Star Rating': '3.2', 'Price': '377', 'Seat Availability': '21 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Hazaribagh to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/hazaribagh-to-patna', 'Bus Name': 'Sadhvi Rath', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '23:28', 'Duration': '06h 02m', 'Reaching Time': '05:30', 'Star Rating': '4.4', 'Price': '630', 'Seat Availability': '20 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Hazaribagh to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/hazaribagh-to-patna', 'Bus Name': 'MAA SHANTI TRAVELS', 'Bus Type': 'A/C Seater/Sleeper (2+1)', 'Departing Time': '23:30', 'Duration': '07h 05m', 'Reaching Time': '06:35', 'Star Rating': '3.6', 'Price': '601', 'Seat Availability': '27 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Hazaribagh to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/hazaribagh-to-patna', 'Bus Name': 'Rekha Luxury', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '23:35', 'Duration': '06h 25m', 'Reaching Time': '06:00', 'Star Rating': '3.9', 'Price': '580', 'Seat Availability': '6 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Hazaribagh to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/hazaribagh-to-patna', 'Bus Name': 'Rajdhani bus service', 'Bus Type': 'Non A/C Seater / Sleeper (2+1)', 'Departing Time': '23:45', 'Duration': '05h 15m', 'Reaching Time': '05:00', 'Star Rating': '3.3', 'Price': '509', 'Seat Availability': '6 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Hazaribagh to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/hazaribagh-to-patna', 'Bus Name': 'Tejas Maa Bhawani', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '21:00', 'Duration': '07h 01m', 'Reaching Time': '04:01', 'Star Rating': '2.1', 'Price': '725', 'Seat Availability': '21 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Hazaribagh to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/hazaribagh-to-patna', 'Bus Name': 'Rajshri Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:50', 'Duration': '07h 00m', 'Reaching Time': '04:50', 'Star Rating': '1.7', 'Price': '429', 'Seat Availability': '37 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Hazaribagh to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/hazaribagh-to-patna', 'Bus Name': 'Arzoo Travels', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '23:30', 'Duration': '05h 30m', 'Reaching Time': '05:00', 'Star Rating': '1.2', 'Price': '570', 'Seat Availability': '14 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Hazaribagh to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/hazaribagh-to-patna', 'Bus Name': 'Prithvi Vahan', 'Bus Type': 'Bharat Benz A/C Sleeper (2+1)', 'Departing Time': '23:45', 'Duration': '05h 25m', 'Reaching Time': '05:10', 'Star Rating': '4.6', 'Price': '810', 'Seat Availability': '2 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Hazaribagh to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/hazaribagh-to-patna', 'Bus Name': 'Mahuli Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '23:59', 'Duration': '06h 16m', 'Reaching Time': '06:15', 'Star Rating': '2.9', 'Price': '600', 'Seat Availability': '30 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Muzaffarpur (Bihar) to Ranchi', 'Route Link': 'https://www.redbus.in/bus-tickets/muzaffarpur-to-ranchi', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 153594', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '18:00', 'Duration': '12h 00m', 'Reaching Time': '06:00', 'Star Rating': '3.9', 'Price': '605', 'Seat Availability': '16 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Muzaffarpur (Bihar) to Ranchi', 'Route Link': 'https://www.redbus.in/bus-tickets/muzaffarpur-to-ranchi', 'Bus Name': 'JGD Travels Pvt Ltd.', 'Bus Type': 'Bharat Benz A/C Sleeper (2+1)', 'Departing Time': '18:10', 'Duration': '10h 15m', 'Reaching Time': '04:25', 'Star Rating': '3.6', 'Price': '990', 'Seat Availability': '4 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Muzaffarpur (Bihar) to Ranchi', 'Route Link': 'https://www.redbus.in/bus-tickets/muzaffarpur-to-ranchi', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '19:15', 'Duration': '10h 45m', 'Reaching Time': '06:00', 'Star Rating': '2.2', 'Price': '700', 'Seat Availability': '11 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Muzaffarpur (Bihar) to Ranchi', 'Route Link': 'https://www.redbus.in/bus-tickets/muzaffarpur-to-ranchi', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '17:45', 'Duration': '11h 00m', 'Reaching Time': '04:45', 'Star Rating': '2.5', 'Price': '750', 'Seat Availability': '12 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Muzaffarpur (Bihar) to Ranchi', 'Route Link': 'https://www.redbus.in/bus-tickets/muzaffarpur-to-ranchi', 'Bus Name': 'Jai Mata Di Tour and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '18:00', 'Duration': '10h 30m', 'Reaching Time': '04:30', 'Star Rating': '2.2', 'Price': '1000', 'Seat Availability': '21 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Muzaffarpur (Bihar) to Ranchi', 'Route Link': 'https://www.redbus.in/bus-tickets/muzaffarpur-to-ranchi', 'Bus Name': 'Tejas Maa Bhawani', 'Bus Type': 'AC Sleeper (2+1)', 'Departing Time': '18:45', 'Duration': '11h 15m', 'Reaching Time': '06:00', 'Star Rating': '2.9', 'Price': '2500', 'Seat Availability': '2 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Muzaffarpur (Bihar) to Ranchi', 'Route Link': 'https://www.redbus.in/bus-tickets/muzaffarpur-to-ranchi', 'Bus Name': 'Tejas Maa Bhawani', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '18:30', 'Duration': '11h 00m', 'Reaching Time': '05:30', 'Star Rating': '2.9', 'Price': '2000', 'Seat Availability': '41 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Raxaul', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-raxaul', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 150571', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '21:20', 'Duration': '07h 10m', 'Reaching Time': '04:30', 'Star Rating': '3.4', 'Price': '293', 'Seat Availability': '32 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Raxaul', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-raxaul', 'Bus Name': 'sapna travels(A.T)', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '21:00', 'Duration': '08h 00m', 'Reaching Time': '05:00', 'Star Rating': '2.8', 'Price': '500', 'Seat Availability': '34 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Raxaul', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-raxaul', 'Bus Name': 'Jai Hanuman Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '22:00', 'Duration': '07h 00m', 'Reaching Time': '05:00', 'Star Rating': '2.2', 'Price': '495', 'Seat Availability': '54 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Purnea to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/purnea-to-patna', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 156563', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '19:00', 'Duration': '09h 00m', 'Reaching Time': '04:00', 'Star Rating': '3.1', 'Price': '468', 'Seat Availability': '33 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Purnea to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/purnea-to-patna', 'Bus Name': 'MAA SHANTI TRAVELS', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:10', 'Duration': '08h 50m', 'Reaching Time': '05:00', 'Star Rating': '4.0', 'Price': '648', 'Seat Availability': '19 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Purnea to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/purnea-to-patna', 'Bus Name': 'Aitiana Airwings', 'Bus Type': 'Benz A/C Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '08h 00m', 'Reaching Time': '05:00', 'Star Rating': '4.3', 'Price': '650', 'Seat Availability': '8 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Purnea to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/purnea-to-patna', 'Bus Name': 'Divya Rath', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '20:30', 'Duration': '09h 00m', 'Reaching Time': '05:30', 'Star Rating': '3.6', 'Price': '700', 'Seat Availability': '3 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Purnea to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/purnea-to-patna', 'Bus Name': 'MAA KAMAKHYA DREAMLINER', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:10', 'Duration': '08h 50m', 'Reaching Time': '05:00', 'Star Rating': '3.8', 'Price': '495', 'Seat Availability': '11 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Purnea to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/purnea-to-patna', 'Bus Name': 'AITIANA CRUISELINERS', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '09h 00m', 'Reaching Time': '06:00', 'Star Rating': '3.6', 'Price': '500', 'Seat Availability': '10 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Purnea to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/purnea-to-patna', 'Bus Name': 'Hawa Hawai', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:30', 'Duration': '09h 00m', 'Reaching Time': '05:30', 'Star Rating': '3.2', 'Price': '495', 'Seat Availability': '7 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Purnea to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/purnea-to-patna', 'Bus Name': 'Maa Satyabhama Rath', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '09h 00m', 'Reaching Time': '06:00', 'Star Rating': '4.0', 'Price': '600', 'Seat Availability': '14 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Purnea to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/purnea-to-patna', 'Bus Name': 'Shatabdi Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '19:50', 'Duration': '09h 00m', 'Reaching Time': '04:50', 'Star Rating': '2.1', 'Price': '650', 'Seat Availability': '17 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Purnea to Patna (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/purnea-to-patna', 'Bus Name': 'Sree Balaji Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '19:30', 'Duration': '09h 00m', 'Reaching Time': '04:30', 'Star Rating': '1.0', 'Price': '450', 'Seat Availability': '4 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Hazaribagh', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-hazaribagh', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 153594', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '20:41', 'Duration': '07h 19m', 'Reaching Time': '04:00', 'Star Rating': '2.9', 'Price': '396', 'Seat Availability': '16 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Hazaribagh', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-hazaribagh', 'Bus Name': 'Rajdhani bus service', 'Bus Type': 'Non A/C Seater / Sleeper (2+1)', 'Departing Time': '18:30', 'Duration': '07h 00m', 'Reaching Time': '01:30', 'Star Rating': '3.3', 'Price': '555', 'Seat Availability': '15 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Hazaribagh', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-hazaribagh', 'Bus Name': 'Rekha Luxury', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:00', 'Duration': '08h 00m', 'Reaching Time': '04:00', 'Star Rating': '4.1', 'Price': '600', 'Seat Availability': '2 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Hazaribagh', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-hazaribagh', 'Bus Name': 'Sri Sai ( Jharkhand Paryatak)', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:00', 'Duration': '07h 30m', 'Reaching Time': '03:30', 'Star Rating': '3.3', 'Price': '473', 'Seat Availability': '12 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Hazaribagh', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-hazaribagh', 'Bus Name': 'Arzoo Travels', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '20:30', 'Duration': '06h 00m', 'Reaching Time': '02:30', 'Star Rating': '3.0', 'Price': '570', 'Seat Availability': '30 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Hazaribagh', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-hazaribagh', 'Bus Name': 'Mahuli Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '07h 00m', 'Reaching Time': '04:00', 'Star Rating': '3.2', 'Price': '642', 'Seat Availability': '32 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Hazaribagh', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-hazaribagh', 'Bus Name': 'Bhawani Travels', 'Bus Type': 'NON A/C Seater Push Back (2+2)', 'Departing Time': '13:25', 'Duration': '07h 50m', 'Reaching Time': '21:15', 'Star Rating': '2.3', 'Price': '449', 'Seat Availability': '40 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Hazaribagh', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-hazaribagh', 'Bus Name': 'Sadhvi Rath', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:40', 'Duration': '06h 00m', 'Reaching Time': '02:40', 'Star Rating': '2.1', 'Price': '540', 'Seat Availability': '48 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Hazaribagh', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-hazaribagh', 'Bus Name': 'Puja Rath', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '06h 30m', 'Reaching Time': '03:30', 'Star Rating': '1.8', 'Price': '540', 'Seat Availability': '22 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Hazaribagh', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-hazaribagh', 'Bus Name': 'KRISHNA RATH LUXURY', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '06h 00m', 'Reaching Time': '03:00', 'Star Rating': '1.9', 'Price': '495', 'Seat Availability': '35 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Darbhanga', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-darbhanga', 'Bus Name': 'Yogmaya', 'Bus Type': 'NON A/C Seater / Sleeper (2+2)', 'Departing Time': '20:45', 'Duration': '05h 45m', 'Reaching Time': '02:30', 'Star Rating': '3.7', 'Price': '350', 'Seat Availability': '64 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Darbhanga', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-darbhanga', 'Bus Name': 'Shiv Ganga Travels', 'Bus Type': 'A/C Seater (2+2)', 'Departing Time': '11:56', 'Duration': '04h 04m', 'Reaching Time': '16:00', 'Star Rating': '1.2', 'Price': '330', 'Seat Availability': '36 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Darbhanga', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-darbhanga', 'Bus Name': 'Sri Krishna Tours and Travels', 'Bus Type': 'A/C Seater Push Back (2+2)', 'Departing Time': '12:00', 'Duration': '05h 25m', 'Reaching Time': '17:25', 'Star Rating': '2.2', 'Price': '330', 'Seat Availability': '16 Seats available'}
# ...
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Motihari to Agra', 'Route Link': 'https://www.redbus.in/bus-tickets/motihari-to-agra', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 137431', 'Bus Type': 'Volvo AC Seater 2+2', 'Departing Time': '17:20', 'Duration': '14h 40m', 'Reaching Time': '08:00', 'Star Rating': '2.2', 'Price': '1300', 'Seat Availability': '7 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Motihari to Agra', 'Route Link': 'https://www.redbus.in/bus-tickets/motihari-to-agra', 'Bus Name': 'Panwar Travels', 'Bus Type': 'A/C Sleeper (2+1)', 'Departing Time': '15:40', 'Duration': '14h 35m', 'Reaching Time': '06:15', 'Star Rating': '2.7', 'Price': '2849', 'Seat Availability': '15 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Motihari to Agra', 'Route Link': 'https://www.redbus.in/bus-tickets/motihari-to-agra', 'Bus Name': 'Baba Khatushyam Travels Pvt Ltd', 'Bus Type': 'A/C Seater / Sleeper (3+1)', 'Departing Time': '17:35', 'Duration': '13h 55m', 'Reaching Time': '07:30', 'Star Rating': '1.6', 'Price': '1199', 'Seat Availability': '55 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Motihari to Agra', 'Route Link': 'https://www.redbus.in/bus-tickets/motihari-to-agra', 'Bus Name': 'Travel Point World LLP', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '18:20', 'Duration': '12h 30m', 'Reaching Time': '06:50', 'Star Rating': '1.5', 'Price': '1614', 'Seat Availability': '38 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Motihari to Agra', 'Route Link': 'https://www.redbus.in/bus-tickets/motihari-to-agra', 'Bus Name': 'Shree Balajee Travels And Cargo', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '15:00', 'Duration': '15h 43m', 'Reaching Time': '06:43', 'Star Rating': '1.3', 'Price': '1529', 'Seat Availability': '46 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-muzaffarpur', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 160830', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '21:30', 'Duration': '02h 31m', 'Reaching Time': '00:01', 'Star Rating': '3.2', 'Price': '129', 'Seat Availability': '52 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-muzaffarpur', 'Bus Name': 'Rohit Sewa', 'Bus Type': 'NON A/C Seater (2+2)', 'Departing Time': '11:40', 'Duration': '02h 00m', 'Reaching Time': '13:40', 'Star Rating': '3.0', 'Price': '130', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-muzaffarpur', 'Bus Name': 'Rohit Sewa', 'Bus Type': 'NON A/C Seater (2+2)', 'Departing Time': '11:50', 'Duration': '02h 00m', 'Reaching Time': '13:50', 'Star Rating': '3.0', 'Price': '130', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-muzaffarpur', 'Bus Name': 'Rohit Sewa', 'Bus Type': 'NON A/C Seater (2+2)', 'Departing Time': '11:55', 'Duration': '02h 00m', 'Reaching Time': '13:55', 'Star Rating': '3.0', 'Price': '130', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-muzaffarpur', 'Bus Name': 'Rohit Sewa', 'Bus Type': 'NON A/C Seater (2+2)', 'Departing Time': '11:55', 'Duration': '02h 00m', 'Reaching Time': '13:55', 'Star Rating': '5.0', 'Price': '130', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-muzaffarpur', 'Bus Name': 'Rohit Sewa', 'Bus Type': 'NON A/C Seater (2+2)', 'Departing Time': '12:00', 'Duration': '02h 00m', 'Reaching Time': '14:00', 'Star Rating': '3.0', 'Price': '130', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-muzaffarpur', 'Bus Name': 'Rohit Sewa', 'Bus Type': 'NON A/C Seater (2+2)', 'Departing Time': '12:28', 'Duration': '02h 00m', 'Reaching Time': '14:28', 'Star Rating': '3.0', 'Price': '130', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-muzaffarpur', 'Bus Name': 'Aman Rath', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:15', 'Duration': '02h 00m', 'Reaching Time': '22:15', 'Star Rating': '4.0', 'Price': '450', 'Seat Availability': '13 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-muzaffarpur', 'Bus Name': 'Rohit Sewa', 'Bus Type': 'NON A/C Seater (2+2)', 'Departing Time': '12:34', 'Duration': '02h 00m', 'Reaching Time': '14:34', 'Star Rating': '3.0', 'Price': '130', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Muzaffarpur (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-muzaffarpur', 'Bus Name': 'Aman Rath', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:45', 'Duration': '02h 00m', 'Reaching Time': '22:45', 'Star Rating': '4.0', 'Price': '450', 'Seat Availability': '13 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Agra to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/agra-to-motihari', 'Bus Name': 'Panwar Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:45', 'Duration': '19h 45m', 'Reaching Time': '17:30', 'Star Rating': '2.7', 'Price': '2375', 'Seat Availability': '21 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Agra to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/agra-to-motihari', 'Bus Name': 'Shree Balajee Travels And Cargo', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '18:00', 'Duration': '15h 00m', 'Reaching Time': '09:00', 'Star Rating': '1.3', 'Price': '1349', 'Seat Availability': '44 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Lucknow to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/lucknow-to-motihari', 'Bus Name': 'Panwar Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:30', 'Duration': '09h 50m', 'Reaching Time': '07:20', 'Star Rating': '4.3', 'Price': '1121', 'Seat Availability': '29 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Lucknow to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/lucknow-to-motihari', 'Bus Name': 'MISHRA BANDHU BUS SERVICE', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:30', 'Duration': '10h 00m', 'Reaching Time': '07:30', 'Star Rating': '3.0', 'Price': '899', 'Seat Availability': '23 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Lucknow to Motihari', 'Route Link': 'https://www.redbus.in/bus-tickets/lucknow-to-motihari', 'Bus Name': 'Shree Balajee Travels And Cargo', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '23:30', 'Duration': '09h 30m', 'Reaching Time': '09:00', 'Star Rating': '1.3', 'Price': '1349', 'Seat Availability': '44 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Motihari to Kathmandu', 'Route Link': 'https://www.redbus.in/bus-tickets/motihari-to-kathmandu', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 166033', 'Bus Type': 'A/C Seater Hi-Tech Push Back (2+2)', 'Departing Time': '17:10', 'Duration': '13h 05m', 'Reaching Time': '06:15', 'Star Rating': '2.8', 'Price': '685', 'Seat Availability': '25 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Motihari to Kathmandu', 'Route Link': 'https://www.redbus.in/bus-tickets/motihari-to-kathmandu', 'Bus Name': 'V.I.P Travels', 'Bus Type': 'A/C Seater Hi-Tech Push Back (2+2)', 'Departing Time': '16:15', 'Duration': '13h 15m', 'Reaching Time': '05:30', 'Star Rating': '1.5', 'Price': '700', 'Seat Availability': '5 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Simrahi Bazar (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-simrahi-bazar-bihar', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 142847', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '21:25', 'Duration': '05h 05m', 'Reaching Time': '02:30', 'Star Rating': '4.6', 'Price': '435', 'Seat Availability': '28 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Simrahi Bazar (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-simrahi-bazar-bihar', 'Bus Name': 'VIJAY RATH', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:30', 'Duration': '06h 30m', 'Reaching Time': '03:00', 'Star Rating': '3.7', 'Price': '500', 'Seat Availability': '12 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Simrahi Bazar (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-simrahi-bazar-bihar', 'Bus Name': 'Mahuli Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:50', 'Duration': '06h 10m', 'Reaching Time': '03:00', 'Star Rating': '3.7', 'Price': '500', 'Seat Availability': '47 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Simrahi Bazar (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-simrahi-bazar-bihar', 'Bus Name': 'Raj Bus Services', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '20:35', 'Duration': '07h 00m', 'Reaching Time': '03:35', 'Star Rating': '3.5', 'Price': '463', 'Seat Availability': '20 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Simrahi Bazar (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-simrahi-bazar-bihar', 'Bus Name': 'Raj Bus Services', 'Bus Type': 'Bharat Benz A/C Seater /Sleeper (2+1)', 'Departing Time': '18:25', 'Duration': '07h 10m', 'Reaching Time': '01:35', 'Star Rating': '3.5', 'Price': '463', 'Seat Availability': '23 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Simrahi Bazar (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-simrahi-bazar-bihar', 'Bus Name': 'Raj Bus Services', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '19:25', 'Duration': '07h 40m', 'Reaching Time': '03:05', 'Star Rating': '3.5', 'Price': '463', 'Seat Availability': '26 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Simrahi Bazar (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-simrahi-bazar-bihar', 'Bus Name': 'Shree Sai Krishna Luxury', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:15', 'Duration': '08h 15m', 'Reaching Time': '05:30', 'Star Rating': '3.8', 'Price': '648', 'Seat Availability': '42 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Simrahi Bazar (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-simrahi-bazar-bihar', 'Bus Name': 'Sri Krishna Tours and Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '20:30', 'Duration': '06h 10m', 'Reaching Time': '02:40', 'Star Rating': '3.2', 'Price': '600', 'Seat Availability': '44 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Simrahi Bazar (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-simrahi-bazar-bihar', 'Bus Name': 'Rukmanti (AT)', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:00', 'Duration': '06h 15m', 'Reaching Time': '02:15', 'Star Rating': '3.0', 'Price': '508', 'Seat Availability': '38 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Simrahi Bazar (Bihar)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-simrahi-bazar-bihar', 'Bus Name': 'Raj Rath', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '21:00', 'Duration': '06h 30m', 'Reaching Time': '03:30', 'Star Rating': '2.4', 'Price': '500', 'Seat Availability': '10 Seats available'}
# Message:
#
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Ramgarh (Jharkhand)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-ramgarh-jharkhand', 'Bus Name': 'Bihar state road transport corporation (BSRTC) - 153594', 'Bus Type': 'AC Seater (2+2)', 'Departing Time': '20:41', 'Duration': '08h 50m', 'Reaching Time': '05:31', 'Star Rating': '2.8', 'Price': '466', 'Seat Availability': '12 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Ramgarh (Jharkhand)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-ramgarh-jharkhand', 'Bus Name': 'Mahuli Travels', 'Bus Type': 'A/C Seater/Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '08h 00m', 'Reaching Time': '05:00', 'Star Rating': '4.4', 'Price': '642', 'Seat Availability': '31 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Ramgarh (Jharkhand)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-ramgarh-jharkhand', 'Bus Name': 'Rekha Luxury', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:00', 'Duration': '08h 45m', 'Reaching Time': '04:45', 'Star Rating': '3.2', 'Price': '600', 'Seat Availability': '2 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Ramgarh (Jharkhand)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-ramgarh-jharkhand', 'Bus Name': 'Chandralok Travels', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:20', 'Duration': '08h 10m', 'Reaching Time': '05:30', 'Star Rating': '2.1', 'Price': '600', 'Seat Availability': '48 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Ramgarh (Jharkhand)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-ramgarh-jharkhand', 'Bus Name': 'Sri Sai ( Jharkhand Paryatak)', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:00', 'Duration': '09h 30m', 'Reaching Time': '05:30', 'Star Rating': '2.7', 'Price': '473', 'Seat Availability': '18 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Ramgarh (Jharkhand)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-ramgarh-jharkhand', 'Bus Name': 'MAA SHANTI TRAVELS', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '20:27', 'Duration': '07h 18m', 'Reaching Time': '03:45', 'Star Rating': '3.8', 'Price': '1203', 'Seat Availability': '6 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Ramgarh (Jharkhand)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-ramgarh-jharkhand', 'Bus Name': 'Puja Rath', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '21:00', 'Duration': '07h 00m', 'Reaching Time': '04:00', 'Star Rating': '2.4', 'Price': '540', 'Seat Availability': '18 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Ramgarh (Jharkhand)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-ramgarh-jharkhand', 'Bus Name': 'Rajdhani bus service', 'Bus Type': 'Non A/C Seater / Sleeper (2+1)', 'Departing Time': '18:30', 'Duration': '07h 45m', 'Reaching Time': '02:15', 'Star Rating': '3.3', 'Price': '555', 'Seat Availability': '28 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Ramgarh (Jharkhand)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-ramgarh-jharkhand', 'Bus Name': 'Maharani Express', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '18:00', 'Duration': '08h 20m', 'Reaching Time': '02:20', 'Star Rating': '2.4', 'Price': '720', 'Seat Availability': '36 Seats available'}
# {'State': 'Bihar', 'Route Name': 'Patna (Bihar) to Ramgarh (Jharkhand)', 'Route Link': 'https://www.redbus.in/bus-tickets/patna-to-ramgarh-jharkhand', 'Bus Name': 'MAA SHANTI TRAVELS', 'Bus Type': 'A/C Seater/Sleeper (2+1)', 'Departing Time': '21:25', 'Duration': '07h 40m', 'Reaching Time': '05:05', 'Star Rating': '2.6', 'Price': '694', 'Seat Availability': '32 Seats available'}
